# %% [markdown]
# # Data Exploration
#
# This notebook will be used to inspect the Handwriting & Personality Traits dataset.
#
# Goals:
# - Load the Kaggle dataset
# - Check columns and missing values
# - Identify handwriting feature columns
# - Identify Big Five personality trait columns
# - Check whether the dataset contains image paths or only structured/tabular data

# %%
import pandas as pd
import numpy as np

DATA_PATH = "../data/raw/handwriting_personality_traits.csv"

# df = pd.read_csv(DATA_PATH)
# df.head()
